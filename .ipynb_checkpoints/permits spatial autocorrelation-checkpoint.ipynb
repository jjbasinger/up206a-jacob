# %% [markdown]
# # Spatial Autocorrelation

# %% [markdown]
# In this notebook I will perform spatial autocorrelation analysis on the building permits for new buildings throughout NYC.

# %%
import pandas as pd
import geopandas as gpd
import sodapy
from sodapy import Socrata
import matplotlib.pyplot as plt
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ## Permit Data

# %% [markdown]
# Using the NYC open data API to access the building permit data as in the last notebook.

# %%
client = Socrata("data.cityofnewyork.us", '9llM0ejMVTKfRxS1XlvL7gXjU')

# %%
permits = client.get("ipu4-2q9a", content_type='json', 
                     select = 'borough, bin__, job_type, block, bldg_type, permit_status, filing_status, permit_type, filing_date, issuance_date, expiration_date, job_start_date, gis_latitude, gis_longitude, gis_census_tract, gis_nta_name',  
                     where = 'permit_type == "NB"', 
                     limit = 300000)

# %%
permitdata = pd.DataFrame.from_records(permits)

# %%
permitdata.head()
# Out:
#      borough    bin__ job_type  block bldg_type permit_status filing_status  \
# 0  MANHATTAN  1090470       NB  00439         2        ISSUED       RENEWAL
# 1   BROOKLYN  3000519       NB  00166         2        ISSUED       RENEWAL
# 2      BRONX  2130661       NB  05937         2        ISSUED       RENEWAL
# 3   BROOKLYN  3428681       NB  06319         1        ISSUED       RENEWAL
# 4   BROOKLYN  3428682       NB  06319         1        ISSUED       RENEWAL
#
#   permit_type filing_date issuance_date expiration_date job_start_date  \
# 0          NB  06/17/2020    06/17/2020      03/25/2021     10/08/2015
# 1          NB  06/17/2020    06/17/2020      09/20/2020     12/07/2018
# 2          NB  06/17/2020    06/17/2020      05/06/2021     01/28/2020
# 3          NB  06/17/2020    06/17/2020      03/19/2021     06/24/2019
# 4          NB  06/17/2020    06/17/2020      03/19/2021     06/24/2019
#
#   gis_latitude gis_longitude gis_census_tract  \
# 0    40.729493    -73.982328               34
# 1    40.687759    -73.982898               37
# 2          NaN           NaN              NaN
# 3    40.603089    -73.991091              296
# 4    40.603051    -73.991029              296
#
#                                        gis_nta_name work_type
# 0                                      East Village       NaN
# 1  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill       NaN
# 2                                               NaN       NaN
# 3                                  Bensonhurst West       NaN
# 4                                  Bensonhurst West       NaN

# %% [markdown]
# Converting the latitude, longitude, and census tracts to numeric data formats.

# %%
permitdata.columns
# Out:
# Index(['borough', 'bin__', 'job_type', 'block', 'bldg_type', 'permit_status',
#        'filing_status', 'permit_type', 'filing_date', 'issuance_date',
#        'expiration_date', 'job_start_date', 'gis_latitude', 'gis_longitude',
#        'gis_census_tract', 'gis_nta_name', 'work_type'],
#       dtype='object')

# %%
for column in ['gis_latitude', 'gis_longitude', 'gis_census_tract']:
    permitdata[column] = pd.to_numeric(permitdata[column], errors='coerce')

# %%
permitdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246564 entries, 0 to 246563
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   borough           246564 non-null  object
#  1   bin__             246564 non-null  object
#  2   job_type          246564 non-null  object
#  3   block             246554 non-null  object
#  4   bldg_type         245172 non-null  object
#  5   permit_status     245358 non-null  object
#  6   filing_status     246564 non-null  object
#  7   permit_type       246564 non-null  object
#  8   filing_date       246563 non-null  object
#  9   issuance_date     245325 non-null  object
#  10  expiration_date   246203 non-null  object
#  11  job_start_date    246558 non-null  object
#  12  gis_latitude      243954 non-null  float64
#  13  gis_longitude     243954 non-null  float64
#  14  gis_census_tract  243954 non-null  float64
#  15  gis_nta_name      243954 non-null  object
#  16  work_type         1 non-null       object
# dtypes: float64(3), object(14)
# memory usage: 32.0+ MB

# %% [markdown]
# Dropping the permits that do not have locations (either the lat and lon locations, or those that do not have a census tract listed).

# %%
permitdata = permitdata.dropna(subset=['gis_longitude','gis_latitude', 'gis_census_tract'])

# %%
permitdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243954 entries, 0 to 246563
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   borough           243954 non-null  object
#  1   bin__             243954 non-null  object
#  2   job_type          243954 non-null  object
#  3   block             243944 non-null  object
#  4   bldg_type         242565 non-null  object
#  5   permit_status     242756 non-null  object
#  6   filing_status     243954 non-null  object
#  7   permit_type       243954 non-null  object
#  8   filing_date       243953 non-null  object
#  9   issuance_date     242726 non-null  object
#  10  expiration_date   243596 non-null  object
#  11  job_start_date    243948 non-null  object
#  12  gis_latitude      243954 non-null  float64
#  13  gis_longitude     243954 non-null  float64
#  14  gis_census_tract  243954 non-null  float64
#  15  gis_nta_name      243954 non-null  object
#  16  work_type         1 non-null       object
# dtypes: float64(3), object(14)
# memory usage: 33.5+ MB

# %% [markdown]
# Adding in a geometry column for when the geodataframe is created.

# %%
permitdata['geometry'] = [Point(xy) for xy in zip(permitdata['gis_longitude'], permitdata['gis_latitude'])]

# %%
permitdata.head()
# Out:
#      borough    bin__ job_type  block bldg_type permit_status filing_status  \
# 0  MANHATTAN  1090470       NB  00439         2        ISSUED       RENEWAL
# 1   BROOKLYN  3000519       NB  00166         2        ISSUED       RENEWAL
# 3   BROOKLYN  3428681       NB  06319         1        ISSUED       RENEWAL
# 4   BROOKLYN  3428682       NB  06319         1        ISSUED       RENEWAL
# 5  MANHATTAN  1090833       NB  00764         2        ISSUED       RENEWAL
#
#   permit_type filing_date issuance_date expiration_date job_start_date  \
# 0          NB  06/17/2020    06/17/2020      03/25/2021     10/08/2015
# 1          NB  06/17/2020    06/17/2020      09/20/2020     12/07/2018
# 3          NB  06/17/2020    06/17/2020      03/19/2021     06/24/2019
# 4          NB  06/17/2020    06/17/2020      03/19/2021     06/24/2019
# 5          NB  06/17/2020    06/17/2020      10/01/2020     11/01/2018
#
#    gis_latitude  gis_longitude  gis_census_tract  \
# 0     40.729493     -73.982328              34.0
# 1     40.687759     -73.982898              37.0
# 3     40.603089     -73.991091             296.0
# 4     40.603051     -73.991029             296.0
# 5     40.739167     -74.001119              81.0
#
#                                        gis_nta_name work_type  \
# 0                                      East Village       NaN
# 1  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill       NaN
# 3                                  Bensonhurst West       NaN
# 4                                  Bensonhurst West       NaN
# 5        Hudson Yards-Chelsea-Flatiron-Union Square       NaN
#
#                                geometry
# 0          POINT (-73.982328 40.729493)
# 1  POINT (-73.98289800000001 40.687759)
# 3          POINT (-73.991091 40.603089)
# 4          POINT (-73.991029 40.603051)
# 5          POINT (-74.001119 40.739167)

# %% [markdown]
# Converting the data to a geodataframe

# %%
permitsgdf= gpd.GeoDataFrame(permitdata, crs='EPSG:4326')

# %%
permitsgdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 243954 entries, 0 to 246563
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   borough           243954 non-null  object
#  1   bin__             243954 non-null  object
#  2   job_type          243954 non-null  object
#  3   block             243944 non-null  object
#  4   bldg_type         242565 non-null  object
#  5   permit_status     242756 non-null  object
#  6   filing_status     243954 non-null  object
#  7   permit_type       243954 non-null  object
#  8   filing_date       243953 non-null  object
#  9   issuance_date     242726 non-null  object
#  10  expiration_date   243596 non-null  object
#  11  job_start_date    243948 non-null  object
#  12  gis_latitude      243954 non-null  float64
#  13  gis_longitude     243954 non-null  float64
#  14  gis_census_tract  243954 non-null  float64
#  15  gis_nta_name      243954 non-null  object
#  16  work_type         1 non-null       object
#  17  geometry          243954 non-null  geometry
# dtypes: float64(3), geometry(1), object(14)
# memory usage: 35.4+ MB

# %%
permitsgdf.head()
# Out:
#      borough    bin__ job_type  block bldg_type permit_status filing_status  \
# 0  MANHATTAN  1090470       NB  00439         2        ISSUED       RENEWAL
# 1   BROOKLYN  3000519       NB  00166         2        ISSUED       RENEWAL
# 3   BROOKLYN  3428681       NB  06319         1        ISSUED       RENEWAL
# 4   BROOKLYN  3428682       NB  06319         1        ISSUED       RENEWAL
# 5  MANHATTAN  1090833       NB  00764         2        ISSUED       RENEWAL
#
#   permit_type filing_date issuance_date expiration_date job_start_date  \
# 0          NB  06/17/2020    06/17/2020      03/25/2021     10/08/2015
# 1          NB  06/17/2020    06/17/2020      09/20/2020     12/07/2018
# 3          NB  06/17/2020    06/17/2020      03/19/2021     06/24/2019
# 4          NB  06/17/2020    06/17/2020      03/19/2021     06/24/2019
# 5          NB  06/17/2020    06/17/2020      10/01/2020     11/01/2018
#
#    gis_latitude  gis_longitude  gis_census_tract  \
# 0     40.729493     -73.982328              34.0
# 1     40.687759     -73.982898              37.0
# 3     40.603089     -73.991091             296.0
# 4     40.603051     -73.991029             296.0
# 5     40.739167     -74.001119              81.0
#
#                                        gis_nta_name work_type  \
# 0                                      East Village       NaN
# 1  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill       NaN
# 3                                  Bensonhurst West       NaN
# 4                                  Bensonhurst West       NaN
# 5        Hudson Yards-Chelsea-Flatiron-Union Square       NaN
#
#                      geometry
# 0  POINT (-73.98233 40.72949)
# 1  POINT (-73.98290 40.68776)
# 3  POINT (-73.99109 40.60309)
# 4  POINT (-73.99103 40.60305)
# 5  POINT (-74.00112 40.73917)

# %%
permitsgdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import datetime

# %%
permitsgdf['job_start_date'] = pd.to_datetime(permitsgdf['job_start_date'])

# %% [markdown]
# Cutting down the dataset to only contain those new buildings that were commenced between the end of Hurricane Sandy, November 2, 2012, and 2030, which appears to be the most realistic projected start date for the upper end of the dataset (there are start dates of 2099 and up that I have decided to exclude).

# %%
post_sandy_permitsgdf = permitsgdf[(permitsgdf['job_start_date']>'2012-11-02') & 
(permitsgdf['job_start_date']<'2030-12-31')]

# %%
post_sandy_permitsgdf.sort_values('job_start_date')
# Out:
#               borough    bin__ job_type  block bldg_type permit_status  \
# 59514   STATEN ISLAND  5158962       NB  06333         1        ISSUED
# 204569          BRONX  2127341       NB  03436         1        ISSUED
# 20133           BRONX  2127341       NB  03436         1        ISSUED
# 148682          BRONX  2127340       NB  03436         1        ISSUED
# 46151           BRONX  2127339       NB  03436         1        ISSUED
# ...               ...      ...      ...    ...       ...           ...
# 3059            BRONX  2816717       NB  02752         2        ISSUED
# 226028       BROOKLYN  3421407       NB  03143         2        ISSUED
# 110536       BROOKLYN  3421407       NB  03143         2        ISSUED
# 103238       BROOKLYN  3388038       NB  01708         1        ISSUED
# 6342         BROOKLYN  3388038       NB  01708         1        ISSUED
#
#        filing_status permit_type  filing_date issuance_date expiration_date  \
# 59514        RENEWAL          NB  2013-03-08    2013-03-08       2014-03-08
# 204569       INITIAL          NB  2012-11-07    2012-11-07       2013-07-01
# 20133        RENEWAL          NB  2013-06-27    2013-06-27       2014-06-27
# 148682       RENEWAL          NB  2015-06-18    2015-06-18       2016-06-17
# 46151        RENEWAL          NB  2013-06-27    2013-06-27       2014-06-27
# ...              ...         ...          ...           ...             ...
# 3059         INITIAL          NB   08/12/2020    08/12/2020      01/25/2021
# 226028       RENEWAL          NB  2018-09-04    2018-09-04       2019-09-04
# 110536       INITIAL          NB  2017-08-22    2017-08-22       2018-08-22
# 103238       INITIAL          NB  2003-01-17    2003-01-17       2003-11-15
# 6342         RENEWAL          NB  2004-03-11    2004-04-27       2004-11-12
#
#        job_start_date  gis_latitude  gis_longitude  gis_census_tract  \
# 59514      2012-11-07     40.536935     -74.192536           17009.0
# 204569     2012-11-07     40.807264     -73.850886               4.0
# 20133      2012-11-07     40.807264     -73.850886               4.0
# 148682     2012-11-07     40.807277     -73.850947               4.0
# 46151      2012-11-07     40.807258     -73.851084               4.0
# ...               ...           ...            ...               ...
# 3059       2025-08-12     40.827879     -73.889965           12101.0
# 226028     2027-08-22     40.702198     -73.933729             425.0
# 110536     2027-08-22     40.702198     -73.933729             425.0
# 103238     2030-01-17     40.678436     -73.927880             299.0
# 6342       2030-01-17     40.678436     -73.927880             299.0
#
#                                            gis_nta_name work_type  \
# 59514                                     Arden Heights       NaN
# 204569  Soundview-Castle Hill-Clason Point-Harding Park       NaN
# 20133   Soundview-Castle Hill-Clason Point-Harding Park       NaN
# 148682  Soundview-Castle Hill-Clason Point-Harding Park       NaN
# 46151   Soundview-Castle Hill-Clason Point-Harding Park       NaN
# ...                                                 ...       ...
# 3059                                 Morrisania-Melrose       NaN
# 226028                                   Bushwick South       NaN
# 110536                                   Bushwick South       NaN
# 103238                              Crown Heights North       NaN
# 6342                                Crown Heights North       NaN
#
#                           geometry
# 59514   POINT (-74.19254 40.53693)
# 204569  POINT (-73.85089 40.80726)
# 20133   POINT (-73.85089 40.80726)
# 148682  POINT (-73.85095 40.80728)
# 46151   POINT (-73.85108 40.80726)
# ...                            ...
# 3059    POINT (-73.88997 40.82788)
# 226028  POINT (-73.93373 40.70220)
# 110536  POINT (-73.93373 40.70220)
# 103238  POINT (-73.92788 40.67844)
# 6342    POINT (-73.92788 40.67844)
#
# [54022 rows x 18 columns]

# %%
post_sandy_permitsgdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 54022 entries, 0 to 246563
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   borough           54022 non-null  object
#  1   bin__             54022 non-null  object
#  2   job_type          54022 non-null  object
#  3   block             54022 non-null  object
#  4   bldg_type         54022 non-null  object
#  5   permit_status     53966 non-null  object
#  6   filing_status     54022 non-null  object
#  7   permit_type       54022 non-null  object
#  8   filing_date       54022 non-null  object
#  9   issuance_date     53756 non-null  object
#  10  expiration_date   53819 non-null  object
#  11  job_start_date    54022 non-null  datetime64[ns]
#  12  gis_latitude      54022 non-null  float64
#  13  gis_longitude     54022 non-null  float64
#  14  gis_census_tract  54022 non-null  float64
#  15  gis_nta_name      54022 non-null  object
#  16  work_type         0 non-null      object
#  17  geometry          54022 non-null  geometry
# dtypes: datetime64[ns](1), float64(3), geometry(1), object(13)
# memory usage: 7.8+ MB

# %% [markdown]
# After sorting for only those new buildings that were first permitted after Hurricane Sandy, we are left with roughly 54,000 entries.  It will be interesting to see where these buildings are located, and to see if there is any correlation with damage from Hurricane Sandy or projected sea level rise.

# %% [markdown]
# ## Census Tract Data

# %% [markdown]
# In another notebook I performed the spatial join and value count analyses for all buildings in each census tract, not just the building permits.  I did this so that we could normalize the number of building permits per tract as a function of the total number of buildings in each tract.  I had to perform this work in another notebook due to the size of the dataset on NYC buildings, but the code can be found here: https://jupyter.idre.ucla.edu/user/jjbasinger@me.com/doc/tree/up206a-jacob/nyc%20all%20buildings%20as%20points.ipynb. I created this notebook first without normalizing the data on new building permits, but decided that it would work better if I compared the permits to the total number of buildings.

# %%
censustracts = gpd.read_file('../buildings_and_tracts.json')

# %%
censustracts.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Eliminating unnecessary columns from the tracts dataset, and renaming some of the remaining.

# %%
censustracts.columns
# Out:
# Index(['borough', 'census_tra', 'Shape__Are', 'Shape__Len', 'buildings_',
#        'geometry'],
#       dtype='object')

# %%
censustracts.columns = ['borough', 'census_tract', 'Shape__Area', 'Shape__Length', 'buildingsnumber', 'geometry']

# %% [markdown]
# Converting the census_tract (FIPS code) information to a number to match the census tract data in the permits dataset.

# %%
censustracts['census_tract'] = censustracts['census_tract'].astype('float')

# %%
censustracts.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2322 entries, 0 to 2321
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   borough          2322 non-null   object
#  1   census_tract     2322 non-null   float64
#  2   Shape__Area      2322 non-null   float64
#  3   Shape__Length    2322 non-null   float64
#  4   buildingsnumber  2322 non-null   int64
#  5   geometry         2322 non-null   geometry
# dtypes: float64(3), geometry(1), int64(1), object(1)
# memory usage: 109.0+ KB

# %%
censustracts.head()
# Out:
#      borough  census_tract   Shape__Area  Shape__Length  buildingsnumber  \
# 0  Manhattan         100.0  1.844391e+06   11022.881944              495
# 1      Bronx         100.0  1.816387e+07   18897.370805              495
# 2   Brooklyn         100.0  2.239607e+06    6553.112624              495
# 3  Manhattan         201.0  9.723121e+05    4754.494868               41
# 4  Manhattan         202.0  3.315114e+06    8568.089568               77
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...
# 1  POLYGON ((-73.87287 40.78598, -73.87289 40.785...
# 2  POLYGON ((-73.99093 40.70077, -73.99088 40.700...
# 3  POLYGON ((-73.98450 40.70952, -73.98655 40.709...
# 4  MULTIPOLYGON (((-73.98364 40.70960, -73.98450 ...

# %%
censustracts.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We now have a geodataframe of all of the census tracts in New York City (along with the number of buildings in each census tract as a result of the other notebook).

# %% [markdown]
# ## Join

# %% [markdown]
# Next we joined the census tracts data to the permits data.

# %%
joingdf = gpd.sjoin(post_sandy_permitsgdf, censustracts)

# %%
joingdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 54022 entries, 0 to 246419
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   borough_left      54022 non-null  object
#  1   bin__             54022 non-null  object
#  2   job_type          54022 non-null  object
#  3   block             54022 non-null  object
#  4   bldg_type         54022 non-null  object
#  5   permit_status     53966 non-null  object
#  6   filing_status     54022 non-null  object
#  7   permit_type       54022 non-null  object
#  8   filing_date       54022 non-null  object
#  9   issuance_date     53756 non-null  object
#  10  expiration_date   53819 non-null  object
#  11  job_start_date    54022 non-null  datetime64[ns]
#  12  gis_latitude      54022 non-null  float64
#  13  gis_longitude     54022 non-null  float64
#  14  gis_census_tract  54022 non-null  float64
#  15  gis_nta_name      54022 non-null  object
#  16  work_type         0 non-null      object
#  17  geometry          54022 non-null  geometry
#  18  index_right       54022 non-null  int64
#  19  borough_right     54022 non-null  object
#  20  census_tract      54022 non-null  float64
#  21  Shape__Area       54022 non-null  float64
#  22  Shape__Length     54022 non-null  float64
#  23  buildingsnumber   54022 non-null  int64
# dtypes: datetime64[ns](1), float64(6), geometry(1), int64(2), object(14)
# memory usage: 10.3+ MB

# %%
joingdf.head()
# Out:
#      borough_left    bin__ job_type  block bldg_type permit_status  \
# 0       MANHATTAN  1090470       NB  00439         2        ISSUED
# 1715    MANHATTAN  1090211       NB  00441         2        ISSUED
# 4239    MANHATTAN  1091652       NB  00406         2        ISSUED
# 4613    MANHATTAN  1091639       NB  00406         2        ISSUED
# 4616    MANHATTAN  1091639       NB  00406         2        ISSUED
#
#      filing_status permit_type filing_date issuance_date  ...  \
# 0          RENEWAL          NB  06/17/2020    06/17/2020  ...
# 1715       RENEWAL          NB  05/24/2019    05/24/2019  ...
# 4239       RENEWAL          NB  10/05/2020    10/05/2020  ...
# 4613       INITIAL          NB  06/24/2020    06/24/2020  ...
# 4616       RENEWAL          NB  10/05/2020    10/05/2020  ...
#
#      gis_census_tract  gis_nta_name  work_type                    geometry  \
# 0                34.0  East Village        NaN  POINT (-73.98233 40.72949)
# 1715             34.0  East Village        NaN  POINT (-73.98219 40.73029)
# 4239             34.0  East Village        NaN  POINT (-73.98100 40.72951)
# 4613             34.0  East Village        NaN  POINT (-73.98041 40.72871)
# 4616             34.0  East Village        NaN  POINT (-73.98041 40.72871)
#
#       index_right borough_right census_tract   Shape__Area  Shape__Length  \
# 0              71     Manhattan       3400.0  1.718451e+06     5503.30704
# 1715           71     Manhattan       3400.0  1.718451e+06     5503.30704
# 4239           71     Manhattan       3400.0  1.718451e+06     5503.30704
# 4613           71     Manhattan       3400.0  1.718451e+06     5503.30704
# 4616           71     Manhattan       3400.0  1.718451e+06     5503.30704
#
#      buildingsnumber
# 0               1602
# 1715            1602
# 4239            1602
# 4613            1602
# 4616            1602
#
# [5 rows x 24 columns]

# %% [markdown]
# Then we created a new dataset of just the number of permits in each census tract.

# %%
permits_by_tract = joingdf.census_tract.value_counts().rename_axis('census_tract').reset_index(name='permits_count')

# %%
permits_by_tract.head()
# Out:
#    census_tract  permits_count
# 0       91603.0            989
# 1         702.0            478
# 2       11203.0            455
# 3      107001.0            428
# 4       19800.0            346

# %%
permits_by_tract[:20].plot.bar(figsize=(20,4),
                             x='census_tract',
                             y='permits_count')
# Out:
# <AxesSubplot:xlabel='census_tract'>

# %% [markdown]
# As you can see above, there is one census tract with almost double the amount of new building permits as the next highest census tract.

# %% [markdown]
# Finally, we merged the permits by tract data with the census tracts data in order to visualize which census tracts have the most new buildings.

# %%
censustracts = censustracts.merge(permits_by_tract, on='census_tract')

# %% [markdown]
# Below you can see the number of new building permits for each census tract since Hurricane Sandy, plotted by borough.

# %%
for borough in ['Manhattan', 'Brooklyn', 'Bronx', 'Staten Island', 'Queens']:
    censustracts[censustracts['borough']==borough].plot(column='permits_count', figsize=(10,10), scheme='quantiles', legend=True)

# %% [markdown]
# ## Normalizing the Permit Data

# %% [markdown]
# We created a column with the number of new building permits normalized by number of buildings per tract.

# %%
censustracts['permits per building'] = censustracts['permits_count'] / censustracts['buildingsnumber']

# %% [markdown]
# This gives us a column with data that shows how many new building permits there are per building in each census tract. Now we can look at the data in a normalized fashion in order to better compare it.

# %%
censustracts.head()
# Out:
#      borough  census_tract   Shape__Area  Shape__Length  buildingsnumber  \
# 0  Manhattan         100.0  1.844391e+06   11022.881944              495
# 1      Bronx         100.0  1.816387e+07   18897.370805              495
# 2   Brooklyn         100.0  2.239607e+06    6553.112624              495
# 3  Manhattan         600.0  2.582705e+06    6976.286329             1678
# 4     Queens         600.0  2.307341e+06    6437.133984             1678
#
#                                             geometry  permits_count  \
# 0  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...             31
# 1  POLYGON ((-73.87287 40.78598, -73.87289 40.785...             31
# 2  POLYGON ((-73.99093 40.70077, -73.99088 40.700...             31
# 3  POLYGON ((-73.99022 40.71441, -73.98934 40.714...             95
# 4  POLYGON ((-73.86047 40.68484, -73.86077 40.684...             95
#
#    permits per building
# 0              0.062626
# 1              0.062626
# 2              0.062626
# 3              0.056615
# 4              0.056615

# %%
for borough in ['Manhattan', 'Brooklyn', 'Bronx', 'Staten Island', 'Queens']:
    censustracts[censustracts['borough']==borough].plot(column='permits per building', figsize=(10,10), scheme='quantiles', legend=True)
